# %%
import pandas as pd

# %%
df = pd.read_csv("Cotacao_Dolar.csv")

# %%
df.head()
# Out:
#          Data Cotação
# 0  30/04/2026    4,96
# 1  29/04/2026    5,01
# 2  28/04/2026    4,98
# 3  27/04/2026    4,98
# 4  24/04/2026    5,00
